# %% [markdown]
# ### Download Yolo repository
# git clone https://github.com/WongKinYiu/yolov7.git

# %% [markdown]
# ### Get weight ans save it tp yolov7 directory
#
# wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-e6e.pt

# %% [markdown]
# ###  Adapt cfg file
#
# - Create copy of yolov7/cfg/training/yolov7.yaml
# - Set number of classes

# %% [markdown]
# ### Create a file name mask.yaml in yolov7/data/ and put the following configurations:
#
# train: ./train
# val: ./val
# test: ./test
#
#
# nc: 3
# names: ['with_mask', 'without_mask', 'mask_weared_incorrect']

# %% [markdown]
# ### Data preparation
#
# - Convert Pascal Voc labels to Yolo format
# - Split data into subfolders

# %%
# package import

import numpy as np
import pandas as pd
import seaborn as sns
import os
import shutil
import xml.etree.ElementTree as ET
import glob

import json

# %%
# Function that convert XML bounding box(xmin, ymin, xmax, ymax)
# https://towardsdatascience.com/convert-pascal-voc-xml-to-yolo-for-object-detection-f969811ccba5
def xml_to_yolo_bbox(bbox, w, h):
    # xmin, ymin, xmax, ymax
    x_center = ((bbox[2] + bbox[0]) / 2) / w
    y_center = ((bbox[3] + bbox[1]) / 2) / h
    width = (bbox[2] - bbox[0]) / w
    height = (bbox[3] - bbox[1]) / h
    return [x_center, y_center, width, height]

def yolo_to_xml_bbox(bbox, w, h):
    # x_center y_center width heigth
    w_half_len = (bbox[2] * w) / 2
    h_half_len = (bbox[3] * h) / 2
    xmin = int((bbox[0] * w) - w_half_len)
    ymin = int((bbox[1] * h) - h_half_len)
    xmax = int((bbox[0] * w) + w_half_len)
    ymax = int((bbox[1] * h) + h_half_len)
    return [xmin, ymin, xmax, ymax]

# %%
# Create folder
def create_folder(path):
    if not os.path.isdir(path):
        os.makedirs(path)

# %%
create_folder('yolov7/train/images')
create_folder('yolov7/train/labels')
create_folder('yolov7/test/images')
create_folder('yolov7/test/labels')
create_folder('yolov7/val/images')
create_folder('yolov7/val/labels')

# %%
# get all files
from sklearn import tree


im_folder = 'images'
_, _, files = next(os.walk(im_folder))
pos = 0
for f in files:
    source_img = os.path.join(im_folder, f)
    if pos < 700:
        dest_folder = 'yolov7/train/'
    elif (pos>= 700 and pos< 800):
        dest_folder = 'yolov7/val/'
    else:
        dest_folder = 'yolov7/test/'
    destination_img = os.path.join(dest_folder,'images', f)
    shutil.copy(source_img, destination_img)

    # Check for corresponding labels
    label_file_basename = os.path.splitext(f)[0]
    label_source_file = f"{label_file_basename}.xml"
    
    label_dest_file = f"{label_file_basename}.txt"

    label_source_path = os.path.join('annotations', label_source_file)
    label_dest_path = os.path.join(dest_folder,'labels', label_dest_file)
    
     # if file exists, copy it to target folder
    if os.path.exists(label_source_path):
       # parse the content of the xml file
       tree = ET.parse(label_source_path)
       root = tree.getroot()
       width = int(root.find("size").find("width").text)
       height = int(root.find("size").find("height").text)
       classes = ['with_mask', 'without_mask', 'mask_weared_incorrect']
       result = []

       for obj in root.findall('object'):
           label = obj.find("name").text
           # check for new classes and append to list
           index = classes.index(label)
           pil_bbox = [int(x.text) for x in obj.find("bndbox")]
           yolo_bbox = xml_to_yolo_bbox(pil_bbox, width, height)
           # convert data to string
           bbox_string = " ".join([str(x) for x in yolo_bbox])
           result.append(f"{index} {bbox_string}")
           if result:
               # generate a YOLO format text file for each xml file
               with open(label_dest_path, "w" , encoding="utf-8") as f:
                   f.write("\n".join(result))

    pos += 1

# %% [markdown]
# ### Training
# python train.py --weights yolov7-e6e.pt --data data/masks.yaml --workers 4 --batch-size 4 --img 416 --cfg cfg/training/yolov7-masks.yaml --name yolov7 --epochs 5

# %% [markdown]
# ### Detection
#
# python detect.py --weights runs/train/yolov7/weights/best.pt --conf 0.4 --img-size 640 --source ./test/images/maksssksksss849.png

# %% [markdown]
# # Detection with YOLOv8
#
# Can be used in command line directly as:
# yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
#
# or python program:

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # load a pretrained model

# %%
result = model("images/maksssksksss0.png")
# Out:
# image 1/1 /Users/elvist/PycharmProjects/CV Projects/Mask_data/images/maksssksksss0.png: 480x640 4 persons, 2 handbags, 1 cell phone, 73.8ms
# Speed: 2.4ms preprocess, 73.8ms inference, 9.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
# !yolo predict model=yolov8n.pt source='images/maksssksksss0.png' conf=0.3

# %%
create_folder('yolov8/train_custom/train/')
create_folder('yolov8/train_custom/test/')
create_folder('yolov8/train_custom/val/')

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8/train_custom/yolov8n.pt")  # load a pretrained model (recommended for training)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    897664  ultralytics.nn.modules.Detect                [80, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3157200 parameters, 3157184 gradients, 8.9 GFLOPs

# %%
# Train model
model.train(data="/Users/elvist/PycharmProjects/CV Projects/Mask_detection/yolov8/train_custom/masks.yaml", epochs=100, imgsz=512, batch=4, verbose=True, device='cpu', workers=8)
metrics = model.val()  # evaluate model performance on the validation set
results = model("yolov8/train_custom/test/images/maksssksksss10.png")
success = model.export(format="onnx")  # export the model to ONNX format
# Out:
# New https://pypi.org/project/ultralytics/8.0.105 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.97 🚀 Python-3.10.9 torch-2.0.0 CPU
# yolo/engine/trainer: task=detect, mode=train, model=yolov8/train_custom/yolov8n.pt, data=/Users/elvist/PycharmProjects/CV Projects/Mask_detection/yolov8/train_custom/masks.yaml, epochs=100, patience=50, batch=4, imgsz=512, save=True, save_period=-1, cache=False, device=cpu, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/detect/train
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.Detect                [3, [64, 128, 256]]
# Model summary: 225 layers, 3011433 parameters, 3011417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias
# train: Scanning /Users/elvist/PycharmProjects/CV Projects/Mask_detection/yolov8/train_custom/train/labels.cache... 700 images, 0 backgrounds, 0 corrupt: 100%|██████████| 700/700 [00:00<?, ?it/s]
# val: Scanning /Users/elvist/PycharmProjects/CV Projects/Mask_detection/yolov8/train_custom/val/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train/labels.jpg...
# Image sizes 512 train, 512 val
# Using 0 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G      2.495      4.394      1.991         25        512:   2%|▏         | 4/175 [00:02<01:46,  1.61it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       1/100         0G      2.329      4.187      1.806         55        512:  14%|█▎        | 24/175 [00:14<01:32,  1.64it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       1/100         0G      1.817      3.467      1.474         49        512:  55%|█████▍    | 96/175 [00:57<00:48,  1.64it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       1/100         0G       1.76      3.226      1.429         30        512:  65%|██████▌   | 114/175 [01:08<00:37,  1.64it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       1/100         0G       1.64      2.728      1.337         30        512: 100%|██████████| 175/175 [01:44<00:00,  1.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  2.80it/s]
#                    all        100        481      0.944      0.217      0.294       0.16
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100         0G      1.335      1.549      1.129         32        512:  79%|███████▉  | 139/175 [01:22<00:20,  1.72it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       2/100         0G      1.334      1.538      1.128         16        512:  88%|████████▊ | 154/175 [01:31<00:12,  1.73it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       2/100         0G      1.342      1.535      1.127         14        512:  93%|█████████▎| 163/175 [01:36<00:06,  1.73it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       2/100         0G      1.355      1.532      1.128         23        512: 100%|██████████| 175/175 [01:43<00:00,  1.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.19it/s]
#                    all        100        481      0.422      0.463      0.425      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100         0G      1.336       1.39      1.095         19        512:   9%|▉         | 16/175 [00:09<01:32,  1.72it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       3/100         0G        1.3      1.368      1.103         23        512:  23%|██▎       | 41/175 [00:24<01:18,  1.72it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       3/100         0G      1.358      1.324      1.091         56        512:  98%|█████████▊| 171/175 [01:41<00:02,  1.71it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       3/100         0G      1.359      1.325      1.092         37        512: 100%|██████████| 175/175 [01:44<00:00,  1.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  2.98it/s]
#                    all        100        481      0.436      0.473      0.503      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100         0G      1.313      1.298      1.078         17        512:  46%|████▋     | 81/175 [00:48<00:55,  1.69it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       4/100         0G      1.308      1.294      1.079         29        512:  48%|████▊     | 84/175 [00:50<00:53,  1.71it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       4/100         0G      1.309      1.264      1.069         19        512:  99%|█████████▉| 173/175 [01:43<00:01,  1.60it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       4/100         0G      1.308      1.262      1.068         44        512: 100%|██████████| 175/175 [01:44<00:00,  1.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.07it/s]
#                    all        100        481      0.792      0.452      0.559      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100         0G      1.257      1.144      1.046         23        512:   9%|▉         | 16/175 [00:09<01:34,  1.69it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       5/100         0G      1.307      1.176       1.08         15        512:  53%|█████▎    | 92/175 [00:54<00:48,  1.71it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       5/100         0G      1.303      1.175       1.08         13        512:  53%|█████▎    | 93/175 [00:55<00:47,  1.72it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       5/100         0G      1.294      1.175      1.075          7        512:  84%|████████▍ | 147/175 [01:27<00:17,  1.63it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       5/100         0G      1.286      1.161      1.069         48        512: 100%|██████████| 175/175 [01:44<00:00,  1.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.16it/s]
#                    all        100        481      0.599      0.511      0.554      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100         0G      1.321      1.135      1.066         30        512:  29%|██▊       | 50/175 [00:29<01:15,  1.66it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       6/100         0G      1.315       1.13      1.064         23        512:  29%|██▉       | 51/175 [00:30<01:13,  1.68it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       6/100         0G      1.319      1.114      1.056         61        512:  39%|███▉      | 68/175 [00:40<01:03,  1.69it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       6/100         0G      1.268      1.097      1.049          9        512:  98%|█████████▊| 172/175 [01:49<00:02,  1.41it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       6/100         0G      1.269      1.098      1.049         41        512: 100%|██████████| 175/175 [01:51<00:00,  1.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  2.80it/s]
#                    all        100        481      0.692       0.59      0.601      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100         0G      1.237      1.064      1.059         27        512:  29%|██▉       | 51/175 [00:34<01:21,  1.52it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       7/100         0G      1.246      1.059      1.063         32        512:  49%|████▊     | 85/175 [00:57<00:59,  1.51it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       7/100         0G      1.244      1.057       1.06         21        512:  51%|█████▏    | 90/175 [01:00<00:59,  1.44it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       7/100         0G      1.235       1.06      1.054         36        512:  75%|███████▍  | 131/175 [01:28<00:29,  1.48it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       7/100         0G      1.226       1.06      1.052         20        512:  85%|████████▍ | 148/175 [01:40<00:17,  1.51it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       7/100         0G      1.226      1.064      1.054         31        512: 100%|██████████| 175/175 [01:58<00:00,  1.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  2.67it/s]
#                    all        100        481      0.675      0.492      0.584      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100         0G      1.189      1.004      1.027         43        512:  13%|█▎        | 22/175 [00:14<01:42,  1.49it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       8/100         0G      1.211      1.043      1.044         48        512:  35%|███▌      | 62/175 [00:41<01:14,  1.51it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       8/100         0G      1.223      1.034       1.04         28        512:  85%|████████▌ | 149/175 [01:40<00:17,  1.50it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       8/100         0G      1.228      1.036      1.044         11        512: 100%|██████████| 175/175 [01:57<00:00,  1.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  2.86it/s]
#                    all        100        481       0.66      0.573      0.632      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100         0G      1.245      0.997      1.042         41        512:  69%|██████▊   | 120/175 [01:20<00:36,  1.49it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       9/100         0G       1.24     0.9898      1.042         15        512:  93%|█████████▎| 162/175 [01:49<00:08,  1.52it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#       9/100         0G      1.235     0.9826       1.04         53        512: 100%|██████████| 175/175 [01:57<00:00,  1.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  2.76it/s]
#                    all        100        481      0.785       0.64      0.692      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100         0G      1.187      0.969      1.031         24        512:  45%|████▍     | 78/175 [00:52<01:05,  1.48it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      10/100         0G      1.183     0.9539      1.031         13        512:  63%|██████▎   | 111/175 [01:16<00:45,  1.40it/s]wandb: Network error (ConnectTimeout), entering retry loop.
#      10/100         0G      1.186     0.9531      1.029         11        512:  66%|██████▌   | 115/175 [01:19<00:40,  1.49it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      10/100         0G      1.176     0.9436      1.031         19        512:  76%|███████▌  | 133/175 [04:10<02:23,  3.42s/it]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      10/100         0G       1.18     0.9448      1.025         39        512:  91%|█████████ | 159/175 [04:28<00:11,  1.44it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      10/100         0G      1.186     0.9485      1.028         31        512: 100%|██████████| 175/175 [04:39<00:00,  1.60s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  2.83it/s]
#                    all        100        481      0.793      0.659      0.722       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100         0G      1.287      1.079      1.061         16        512:   1%|          | 2/175 [00:01<01:53,  1.52it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      11/100         0G      1.242     0.9758      1.027         51        512:  44%|████▍     | 77/175 [31:18<01:08,  1.44it/s]    libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      11/100         0G      1.233     0.9736      1.027         16        512:  46%|████▌     | 80/175 [31:21<01:05,  1.44it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      11/100         0G      1.226     0.9545      1.023         26        512:  54%|█████▍    | 95/175 [32:58<02:57,  2.22s/it]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      11/100         0G      1.201      0.923      1.018         24        512: 100%|██████████| 175/175 [34:12<00:00, 11.73s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.23it/s]
#                    all        100        481       0.74      0.657      0.696      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100         0G      1.167     0.9283      1.013         27        512:   9%|▊         | 15/175 [00:09<01:36,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      12/100         0G      1.182     0.9215       1.01         26        512:  55%|█████▍    | 96/175 [00:57<00:47,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      12/100         0G      1.179     0.9207      1.012         20        512:  63%|██████▎   | 111/175 [01:06<00:38,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      12/100         0G      1.179     0.9153      1.014         20        512:  74%|███████▎  | 129/175 [01:17<00:28,  1.62it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      12/100         0G      1.187     0.9084      1.013         18        512: 100%|██████████| 175/175 [01:45<00:00,  1.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.08it/s]
#                    all        100        481      0.915      0.709      0.768      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100         0G      1.213     0.8477      1.021         49        512:   3%|▎         | 5/175 [00:03<01:45,  1.62it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      13/100         0G      1.207     0.8888      1.021         27        512:  50%|█████     | 88/175 [00:52<00:51,  1.69it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      13/100         0G      1.183     0.8798      1.019         33        512: 100%|██████████| 175/175 [01:45<00:00,  1.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:03<00:00,  3.26it/s]
#                    all        100        481      0.886      0.661      0.747      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100         0G      1.174     0.8542      1.025         24        512:  13%|█▎        | 22/175 [00:13<01:34,  1.62it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      14/100         0G      1.171     0.8617      1.023         16        512:  43%|████▎     | 75/175 [00:45<00:59,  1.68it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      14/100         0G      1.175     0.8582      1.024         16        512:  63%|██████▎   | 111/175 [01:07<00:38,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      14/100         0G      1.172     0.8599      1.021         18        512:  83%|████████▎ | 145/175 [01:27<00:18,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      14/100         0G      1.171     0.8562       1.02         20        512:  97%|█████████▋| 169/175 [01:42<00:03,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      14/100         0G      1.172     0.8536      1.017         50        512: 100%|██████████| 175/175 [01:45<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.15it/s]
#                    all        100        481      0.776      0.709      0.763      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100         0G      1.179     0.8394      1.004         24        512:  21%|██        | 37/175 [00:22<01:21,  1.70it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      15/100         0G      1.167     0.8351      1.007         25        512:  46%|████▌     | 80/175 [00:48<00:58,  1.62it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      15/100         0G       1.16     0.8322      1.007         11        512:  87%|████████▋ | 152/175 [01:31<00:13,  1.70it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      15/100         0G      1.157     0.8319      1.006         39        512:  90%|████████▉ | 157/175 [01:35<00:11,  1.56it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      15/100         0G      1.158      0.836      1.005         21        512: 100%|██████████| 175/175 [01:45<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:03<00:00,  3.28it/s]
#                    all        100        481      0.874      0.678      0.748      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100         0G      1.129     0.8117      1.011         29        512:  26%|██▌       | 45/175 [00:27<01:16,  1.71it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      16/100         0G      1.129     0.8105       1.01         56        512:  26%|██▋       | 46/175 [00:27<01:15,  1.71it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      16/100         0G      1.129     0.8117      1.008         29        512:  27%|██▋       | 48/175 [00:28<01:13,  1.72it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      16/100         0G      1.142     0.8406      1.014         28        512:  42%|████▏     | 74/175 [00:44<01:00,  1.68it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      16/100         0G      1.163      0.826      1.011         15        512:  95%|█████████▍| 166/175 [01:40<00:06,  1.49it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      16/100         0G       1.16     0.8274      1.013         26        512: 100%|██████████| 175/175 [01:45<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.19it/s]
#                    all        100        481       0.83      0.604      0.689      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100         0G      1.188     0.8209     0.9966         42        512:  10%|█         | 18/175 [00:10<01:32,  1.70it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      17/100         0G      1.206     0.8501      1.016         10        512:  24%|██▍       | 42/175 [00:25<01:22,  1.60it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      17/100         0G      1.201     0.8546      1.023         26        512:  33%|███▎      | 58/175 [00:35<01:12,  1.62it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      17/100         0G      1.189     0.8523      1.019         50        512:  37%|███▋      | 64/175 [00:38<01:07,  1.64it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      17/100         0G      1.158     0.8192       1.01         14        512: 100%|██████████| 175/175 [01:45<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.17it/s]
#                    all        100        481      0.854      0.684       0.75      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100         0G      1.137     0.8365     0.9878         24        512:  24%|██▍       | 42/175 [00:25<01:18,  1.69it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      18/100         0G      1.132     0.8222     0.9899         17        512:  38%|███▊      | 66/175 [00:40<01:05,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      18/100         0G      1.135     0.8114     0.9952         82        512:  57%|█████▋    | 99/175 [01:00<00:46,  1.63it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      18/100         0G      1.142     0.8008     0.9942         75        512:  81%|████████  | 142/175 [01:26<00:20,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      18/100         0G      1.145     0.8031     0.9964         37        512:  87%|████████▋ | 152/175 [01:32<00:13,  1.67it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      18/100         0G      1.144     0.8045     0.9971         13        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.01it/s]
#                    all        100        481      0.871      0.728      0.794      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100         0G       1.23     0.8858      1.025          5        512:  10%|█         | 18/175 [00:10<01:35,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      19/100         0G      1.153     0.8315     0.9999         34        512:  40%|████      | 70/175 [00:42<01:03,  1.66it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      19/100         0G      1.151     0.8251      0.999         42        512:  48%|████▊     | 84/175 [00:50<00:53,  1.69it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      19/100         0G      1.149     0.8202     0.9982         30        512:  53%|█████▎    | 92/175 [00:55<00:49,  1.68it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      19/100         0G      1.148     0.8165     0.9983         19        512:  57%|█████▋    | 100/175 [01:00<00:45,  1.64it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      19/100         0G      1.145     0.8032      1.001         16        512:  96%|█████████▌| 168/175 [01:42<00:04,  1.66it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      19/100         0G      1.144     0.7998     0.9998         50        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.24it/s]
#                    all        100        481      0.726      0.749      0.762      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100         0G      1.025     0.6956     0.9764         24        512:   1%|          | 2/175 [00:01<01:42,  1.69it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      20/100         0G      1.116     0.7821      1.034         30        512:  17%|█▋        | 29/175 [00:17<01:30,  1.61it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      20/100         0G      1.114     0.7663      1.019         25        512:  67%|██████▋   | 118/175 [01:11<00:33,  1.70it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      20/100         0G      1.116     0.7618       1.01         21        512:  93%|█████████▎| 163/175 [01:38<00:07,  1.62it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      20/100         0G      1.117     0.7604      1.009         27        512: 100%|██████████| 175/175 [01:46<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  2.86it/s]
#                    all        100        481      0.877      0.658       0.79      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100         0G      1.165     0.8421      1.001         31        512:   7%|▋         | 12/175 [00:07<01:38,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      21/100         0G      1.148     0.8109     0.9987         28        512:  10%|▉         | 17/175 [00:10<01:43,  1.52it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      21/100         0G      1.137     0.7828     0.9862         33        512:  39%|███▉      | 68/175 [00:41<01:04,  1.66it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      21/100         0G      1.137     0.7682      0.997         11        512: 100%|██████████| 175/175 [01:47<00:00,  1.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.19it/s]
#                    all        100        481      0.836      0.719      0.759      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100         0G      1.103     0.7367     0.9847         40        512:  19%|█▉        | 34/175 [00:20<01:24,  1.67it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      22/100         0G      1.119     0.7558      1.001         15        512:  55%|█████▍    | 96/175 [00:58<00:47,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      22/100         0G       1.12     0.7552     0.9991         25        512:  65%|██████▌   | 114/175 [01:09<00:36,  1.66it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      22/100         0G       1.12     0.7544     0.9972         35        512: 100%|██████████| 175/175 [01:47<00:00,  1.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:03<00:00,  3.27it/s]
#                    all        100        481      0.803      0.697      0.767      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100         0G      1.095     0.6861     0.9715         39        512:   3%|▎         | 6/175 [00:03<01:42,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      23/100         0G      1.089     0.7282     0.9855         41        512:  78%|███████▊  | 137/175 [01:23<00:23,  1.64it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      23/100         0G      1.088      0.723     0.9862         36        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.14it/s]
#                    all        100        481      0.813      0.719      0.764      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100         0G      1.068     0.7519      1.032         16        512:   6%|▌         | 10/175 [00:06<01:39,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      24/100         0G      1.094     0.7149     0.9927         37        512:  59%|█████▉    | 103/175 [01:02<00:43,  1.66it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      24/100         0G      1.094     0.7115     0.9948         21        512:  64%|██████▍   | 112/175 [01:08<00:37,  1.70it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      24/100         0G      1.102     0.7142     0.9952         20        512:  71%|███████▏  | 125/175 [01:16<00:29,  1.67it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      24/100         0G      1.099     0.7255     0.9986         41        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.01it/s]
#                    all        100        481      0.829      0.673      0.721      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100         0G      1.118     0.7083      0.966         28        512:   7%|▋         | 12/175 [00:07<01:37,  1.67it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      25/100         0G      1.099     0.7218     0.9722         19        512:  34%|███▎      | 59/175 [00:35<01:09,  1.67it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      25/100         0G       1.08     0.7031     0.9752         28        512:  65%|██████▍   | 113/175 [01:08<00:38,  1.62it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      25/100         0G      1.082     0.7032     0.9783         28        512:  95%|█████████▌| 167/175 [01:41<00:04,  1.67it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      25/100         0G      1.083      0.704     0.9797          9        512: 100%|██████████| 175/175 [01:46<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  2.88it/s]
#                    all        100        481       0.84       0.69      0.761        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100         0G      1.117     0.7084     0.9829         45        512:  47%|████▋     | 82/175 [00:49<00:55,  1.68it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      26/100         0G      1.108     0.7066     0.9822         44        512:  62%|██████▏   | 108/175 [01:05<00:40,  1.67it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      26/100         0G      1.116       0.71     0.9813         22        512:  69%|██████▉   | 121/175 [01:13<00:32,  1.66it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      26/100         0G      1.124     0.7199      0.988         21        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.19it/s]
#                    all        100        481      0.813      0.709      0.761      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100         0G      1.111      0.712     0.9949         25        512:  53%|█████▎    | 93/175 [00:57<00:49,  1.66it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      27/100         0G      1.099     0.7097     0.9917         28        512:  94%|█████████▍| 165/175 [01:41<00:05,  1.68it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      27/100         0G      1.099     0.7089      0.991         23        512: 100%|██████████| 175/175 [01:47<00:00,  1.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.08it/s]
#                    all        100        481      0.874        0.7      0.776       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100         0G      1.012      0.698      0.968          9        512:   8%|▊         | 14/175 [00:08<01:42,  1.57it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      28/100         0G       1.07     0.7181     0.9726         43        512:  27%|██▋       | 48/175 [00:29<01:18,  1.61it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      28/100         0G      1.074     0.7111     0.9729         37        512:  41%|████      | 71/175 [00:43<01:04,  1.62it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      28/100         0G      1.078     0.7048     0.9729         27        512:  47%|████▋     | 83/175 [00:50<00:58,  1.58it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      28/100         0G      1.096     0.7014     0.9782         26        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.21it/s]
#                    all        100        481      0.888      0.664      0.781      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100         0G      1.098     0.7185     0.9824         32        512:  54%|█████▍    | 95/175 [00:57<00:46,  1.71it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      29/100         0G      1.088     0.7116     0.9858         21        512:  87%|████████▋ | 152/175 [01:32<00:13,  1.70it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      29/100         0G      1.084     0.7081     0.9841         50        512:  91%|█████████ | 159/175 [01:36<00:09,  1.68it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      29/100         0G      1.087      0.712     0.9846         20        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.08it/s]
#                    all        100        481      0.899      0.697      0.779      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100         0G      1.088     0.6771     0.9762         20        512:  26%|██▋       | 46/175 [00:27<01:16,  1.68it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      30/100         0G      1.085     0.6781     0.9826         13        512:  56%|█████▌    | 98/175 [00:59<00:45,  1.69it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      30/100         0G      1.098     0.6835     0.9799         23        512:  70%|███████   | 123/175 [01:14<00:31,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      30/100         0G      1.095     0.6824     0.9812         28        512:  86%|████████▌ | 150/175 [01:31<00:15,  1.64it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      30/100         0G      1.098     0.6885     0.9782         39        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.02it/s]
#                    all        100        481      0.839      0.694      0.797      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100         0G      1.062     0.6634     0.9704         36        512:   9%|▊         | 15/175 [00:08<01:34,  1.70it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      31/100         0G      1.068     0.6728     0.9794         48        512:  15%|█▌        | 27/175 [00:16<01:29,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      31/100         0G       1.03     0.6541     0.9722         28        512:  31%|███       | 54/175 [00:32<01:12,  1.67it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      31/100         0G      1.025     0.6512     0.9685         31        512:  35%|███▌      | 62/175 [00:37<01:07,  1.66it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      31/100         0G      1.053     0.6641     0.9739         46        512:  75%|███████▍  | 131/175 [01:19<00:26,  1.67it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      31/100         0G      1.053     0.6641     0.9732         46        512:  98%|█████████▊| 172/175 [01:44<00:01,  1.53it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      31/100         0G      1.053     0.6643     0.9733         32        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.23it/s]
#                    all        100        481      0.839      0.771      0.816      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100         0G      1.061     0.6881     0.9886         21        512:  61%|██████    | 106/175 [01:04<00:41,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      32/100         0G      1.061     0.6868     0.9842         34        512:  65%|██████▌   | 114/175 [01:09<00:36,  1.69it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      32/100         0G      1.061     0.6844     0.9817         28        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.05it/s]
#                    all        100        481      0.819      0.709      0.778      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100         0G      1.101     0.6962     0.9731         58        512:  58%|█████▊    | 101/175 [01:01<00:44,  1.67it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      33/100         0G      1.101     0.6914     0.9722         20        512:  61%|██████    | 107/175 [01:05<00:41,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      33/100         0G      1.086     0.6769     0.9725         16        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.18it/s]
#                    all        100        481      0.783      0.693       0.76      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100         0G       1.05     0.5975     0.9466         27        512:   3%|▎         | 6/175 [00:03<01:48,  1.56it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      34/100         0G      1.051     0.6532     0.9724         23        512:  73%|███████▎  | 128/175 [01:18<00:28,  1.64it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      34/100         0G       1.06     0.6514     0.9733         36        512: 100%|██████████| 175/175 [01:47<00:00,  1.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.21it/s]
#                    all        100        481      0.838      0.708      0.774      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100         0G      1.082       0.68     0.9709         33        512:  29%|██▉       | 51/175 [00:31<01:16,  1.62it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      35/100         0G      1.077     0.6805     0.9751         51        512:  42%|████▏     | 73/175 [00:44<01:02,  1.63it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      35/100         0G      1.086     0.6783     0.9825         20        512:  62%|██████▏   | 108/175 [01:05<00:41,  1.63it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      35/100         0G      1.081     0.6725     0.9802         14        512:  74%|███████▎  | 129/175 [01:18<00:27,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      35/100         0G      1.078     0.6682     0.9801         25        512:  92%|█████████▏| 161/175 [01:37<00:08,  1.66it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      35/100         0G      1.074     0.6641     0.9804         16        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.14it/s]
#                    all        100        481      0.872       0.75      0.812      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100         0G      1.118     0.6528     0.9507         59        512:   8%|▊         | 14/175 [00:08<01:37,  1.66it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      36/100         0G      1.111     0.6749     0.9604         32        512:  18%|█▊        | 31/175 [00:19<01:27,  1.64it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      36/100         0G      1.076     0.6662      0.973         54        512:  57%|█████▋    | 100/175 [01:01<00:45,  1.64it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      36/100         0G      1.067     0.6597     0.9749         26        512:  66%|██████▋   | 116/175 [01:11<00:39,  1.50it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      36/100         0G      1.061     0.6598     0.9751         20        512: 100%|██████████| 175/175 [01:47<00:00,  1.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:03<00:00,  3.27it/s]
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.06it/s]
#                    all        100        481      0.864      0.765      0.823      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100         0G     0.8851     0.4776      0.913         25        512:  25%|██▍       | 43/175 [00:26<01:20,  1.63it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      90/100         0G     0.8914     0.4805     0.9103         11        512:  58%|█████▊    | 102/175 [01:02<00:45,  1.62it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      90/100         0G     0.8967     0.4801     0.9115         78        512:  67%|██████▋   | 117/175 [01:11<00:36,  1.58it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      90/100         0G     0.8921     0.4775     0.9105         19        512:  69%|██████▉   | 121/175 [01:14<00:33,  1.62it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      90/100         0G     0.8868     0.4741     0.9108         38        512:  82%|████████▏ | 144/175 [01:28<00:19,  1.62it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      90/100         0G      0.884     0.4747     0.9092         25        512: 100%|██████████| 175/175 [01:47<00:00,  1.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:03<00:00,  3.29it/s]
#                    all        100        481      0.896       0.78       0.83      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100         0G       0.85     0.4601     0.9064         19        512:  45%|████▍     | 78/175 [00:47<00:57,  1.69it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      91/100         0G      0.865     0.4574     0.9056         20        512:  80%|████████  | 140/175 [01:25<00:20,  1.70it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      91/100         0G     0.8662     0.4595     0.9056         68        512:  94%|█████████▎| 164/175 [01:40<00:07,  1.51it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      91/100         0G     0.8654     0.4595     0.9056         17        512:  96%|█████████▌| 168/175 [01:42<00:04,  1.66it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      91/100         0G     0.8642     0.4591     0.9041         15        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.07it/s]
#                    all        100        481      0.872      0.773      0.827      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100         0G     0.8865     0.4672     0.9101         18        512:  55%|█████▌    | 97/175 [00:59<00:50,  1.55it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      92/100         0G     0.8725     0.4685     0.9059         30        512: 100%|██████████| 175/175 [01:47<00:00,  1.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.05it/s]
#                    all        100        481      0.883      0.751      0.825      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100         0G      0.876     0.4686     0.9075         59        512:  44%|████▍     | 77/175 [00:47<00:58,  1.67it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      93/100         0G     0.8683      0.471     0.9067         54        512:  55%|█████▌    | 97/175 [00:59<00:45,  1.70it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      93/100         0G       0.87      0.474     0.9049         17        512:  77%|███████▋  | 135/175 [01:22<00:23,  1.67it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      93/100         0G     0.8676     0.4671     0.9071          9        512: 100%|██████████| 175/175 [01:47<00:00,  1.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.19it/s]
#                    all        100        481      0.887      0.741      0.828      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100         0G     0.8386     0.4541     0.9077         68        512:  83%|████████▎ | 146/175 [01:28<00:18,  1.60it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      94/100         0G      0.837     0.4538     0.9081         22        512:  86%|████████▌ | 150/175 [01:31<00:15,  1.62it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      94/100         0G     0.8334     0.4525     0.9059         19        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.18it/s]
#                    all        100        481      0.912      0.743      0.824      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100         0G     0.8048     0.4505       0.87         11        512:   3%|▎         | 5/175 [00:03<01:47,  1.58it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      95/100         0G     0.8428     0.4454     0.9074         20        512:  30%|███       | 53/175 [00:32<01:15,  1.63it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      95/100         0G     0.8499     0.4456     0.9081         36        512:  38%|███▊      | 66/175 [00:40<01:08,  1.60it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      95/100         0G     0.8527     0.4478     0.9098         24        512:  41%|████      | 71/175 [00:43<01:03,  1.63it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      95/100         0G     0.8522     0.4492     0.9103         18        512:  43%|████▎     | 76/175 [00:46<00:59,  1.68it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      95/100         0G     0.8469      0.449     0.9076         23        512:  55%|█████▌    | 97/175 [00:59<00:50,  1.56it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      95/100         0G     0.8591     0.4547     0.9026         32        512: 100%|██████████| 175/175 [01:47<00:00,  1.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.10it/s]
#                    all        100        481      0.893      0.743      0.821      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100         0G     0.8725     0.4657     0.9064         28        512:  43%|████▎     | 76/175 [00:45<00:58,  1.68it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      96/100         0G     0.8722     0.4651     0.9051         18        512:  50%|████▉     | 87/175 [00:52<00:55,  1.57it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      96/100         0G     0.8655     0.4581     0.9014         53        512:  83%|████████▎ | 145/175 [01:27<00:19,  1.53it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      96/100         0G     0.8602     0.4553     0.8992         43        512: 100%|██████████| 175/175 [01:45<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  2.98it/s]
#                    all        100        481      0.861      0.773      0.822      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100         0G     0.8581     0.4703     0.8725         28        512:   2%|▏         | 4/175 [00:02<01:42,  1.67it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      97/100         0G     0.8645      0.459     0.9028         25        512:  51%|█████▏    | 90/175 [00:55<00:52,  1.61it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      97/100         0G     0.8582     0.4522     0.8995         33        512:  64%|██████▍   | 112/175 [01:08<00:38,  1.66it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      97/100         0G     0.8588     0.4522     0.9006         36        512:  66%|██████▋   | 116/175 [01:11<00:35,  1.64it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      97/100         0G     0.8634     0.4536     0.9002         35        512:  71%|███████▏  | 125/175 [01:16<00:29,  1.67it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      97/100         0G      0.857     0.4577     0.8996         22        512: 100%|██████████| 175/175 [01:47<00:00,  1.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.15it/s]
#                    all        100        481      0.834      0.778      0.814      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100         0G     0.8732     0.4491     0.8966         70        512:  27%|██▋       | 47/175 [00:28<01:19,  1.60it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      98/100         0G     0.8457      0.449     0.9023         22        512:  60%|██████    | 105/175 [01:03<00:43,  1.61it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      98/100         0G     0.8507     0.4527      0.902         15        512:  75%|███████▍  | 131/175 [01:19<00:26,  1.64it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      98/100         0G     0.8434     0.4533     0.8993         19        512: 100%|██████████| 175/175 [01:46<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.08it/s]
#                    all        100        481      0.833       0.78       0.82      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100         0G     0.8487     0.4424     0.8855         29        512:  22%|██▏       | 38/175 [00:23<01:25,  1.61it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      99/100         0G     0.8492     0.4555     0.8992         30        512:  48%|████▊     | 84/175 [00:51<00:55,  1.65it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#      99/100         0G     0.8471     0.4517     0.8975         26        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:03<00:00,  3.30it/s]
#                    all        100        481      0.886      0.742      0.821      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100         0G     0.8634     0.4599     0.8957         23        512:  67%|██████▋   | 117/175 [01:11<00:34,  1.67it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#     100/100         0G      0.857     0.4549      0.895         35        512:  81%|████████  | 141/175 [01:26<00:21,  1.62it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#     100/100         0G     0.8529     0.4525     0.8944         45        512:  93%|█████████▎| 163/175 [01:39<00:07,  1.61it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#     100/100         0G     0.8549      0.453     0.8945         27        512:  95%|█████████▍| 166/175 [01:41<00:05,  1.66it/s]libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#     100/100         0G     0.8523     0.4526     0.8957         23        512: 100%|██████████| 175/175 [01:46<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  2.90it/s]
#                    all        100        481      0.884      0.729      0.822      0.569
#
# 100 epochs completed in 3.680 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.97 🚀 Python-3.10.9 torch-2.0.0 CPU
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:03<00:00,  3.54it/s]
#                    all        100        481      0.879      0.753       0.83      0.585
#              with_mask        100        311      0.942      0.881      0.961      0.686
#           without_mask        100        156      0.912      0.735       0.86      0.535
#  mask_weared_incorrect        100         14      0.782      0.643      0.669      0.534
# Speed: 0.3ms preprocess, 26.8ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to runs/detect/train
# Ultralytics YOLOv8.0.97 🚀 Python-3.10.9 torch-2.0.0 CPU
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /Users/elvist/PycharmProjects/CV Projects/Mask_detection/yolov8/train_custom/val/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 25/25 [00:03<00:00,  6.32it/s]
#                    all        100        481      0.869      0.757      0.825       0.58
#              with_mask        100        311      0.939      0.888      0.961      0.685
#           without_mask        100        156      0.899      0.741      0.863      0.535
#  mask_weared_incorrect        100         14       0.77      0.643       0.65       0.52
# Speed: 0.3ms preprocess, 30.8ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to runs/detect/val
#
# image 1/1 /Users/elvist/PycharmProjects/CV Projects/Mask_detection/yolov8/train_custom/test/images/maksssksksss10.png: 512x416 1 with_mask, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
# Ultralytics YOLOv8.0.97 🚀 Python-3.10.9 torch-2.0.0 CPU
#
# PyTorch: starting from runs/detect/train/weights/best.pt with input shape (4, 3, 512, 512) BCHW and output shape(s) (4, 7, 5376) (5.9 MB)
#
# ONNX: starting export with onnx 1.14.0 opset 17...
# ONNX: export success ✅ 0.6s, saved as runs/detect/train/weights/best.onnx (11.6 MB)
#
# Export complete (0.9s)
# Results saved to /Users/elvist/PycharmProjects/CV Projects/Mask_detection/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.onnx imgsz=512
# Validate:        yolo val task=detect model=runs/detect/train/weights/best.onnx imgsz=512 data=/Users/elvist/PycharmProjects/CV Projects/Mask_detection/yolov8/train_custom/masks.yaml
# Visualize:       https://netron.app
# ================ Diagnostic Run torch.onnx.export version 2.0.0 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %%
from ultralytics import YOLO
model = YOLO("runs/detect/train/weights/best.pt")

# %%
for result in results:
    print(result.boxes)
# Out:
# WARNING ⚠️ 'Boxes.boxes' is deprecated. Use 'Boxes.data' instead.
# ultralytics.yolo.engine.results.Boxes object with attributes:
#
# boxes: tensor([[ 97.3347, 265.5527, 193.2753, 386.2927,   0.9226,   0.0000]])
# cls: tensor([0.])
# conf: tensor([0.9226])
# data: tensor([[ 97.3347, 265.5527, 193.2753, 386.2927,   0.9226,   0.0000]])
# id: None
# is_track: False
# orig_shape: tensor([400, 301])
# shape: torch.Size([1, 6])
# xywh: tensor([[145.3050, 325.9227,  95.9406, 120.7400]])
# xywhn: tensor([[0.4827, 0.8148, 0.3187, 0.3018]])
# xyxy: tensor([[ 97.3347, 265.5527, 193.2753, 386.2927]])
# xyxyn: tensor([[0.3234, 0.6639, 0.6421, 0.9657]])

# %%
results = model("yolov8/train_custom/test/images/maksssksksss690.png")
# Out:
# image 1/1 /Users/elvist/PycharmProjects/CV Projects/Mask_data/yolov8/train_custom/test/images/maksssksksss690.png: 320x512 3 with_masks, 70.5ms
# Speed: 1.2ms preprocess, 70.5ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 512)

# %%
import cv2
from google.colab.patches import cv2_imshow # on colab only
res = results[0].plot()
#cv2.imshow("result", res)
cv2_imshow(res)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
